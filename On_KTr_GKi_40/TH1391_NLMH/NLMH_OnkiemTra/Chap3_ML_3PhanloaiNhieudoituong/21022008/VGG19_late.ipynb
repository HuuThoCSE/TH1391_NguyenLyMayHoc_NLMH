# %% [markdown]
# ## ***21022008 Nguyễn Hữu Thọ***

# %% [markdown]
# ```
# MSSV
# ├── dataset
# │   ├── annotations
# │   │   ├── apple.csv
# │   │   ├── banana.csv
# │   │   └── orange.csv
# │   └── images
# │       ├── apple [70 entries]
# │       ├── banana [70 entries]
# │       └── orange [70 entries]
# └── output
#     ├── plots
#     │   ├── accs.png
#     │   └── losses.png
#     ├── detector.h5
#     └── lb.pickle
# ```

# %%
# import os
# import glob
# import pandas as pd
# import xml.etree.ElementTree as ET

# %%
# def xml_to_csv(path):
#     xml_list = []
#     for xml_file in glob.glob(path + '/*.xml'):
#         tree = ET.parse(xml_file)
#         root = tree.getroot()
#         for member in root.findall('object'):
#             bbx = member.find('bndbox')
#             xmin = int(bbx.find('xmin').text)
#             ymin = int(bbx.find('ymin').text)
#             xmax = int(bbx.find('xmax').text)
#             ymax = int(bbx.find('ymax').text)
#             label = member.find('name').text

#             value = (root.find('filename').text,
#                      int(root.find('size')[0].text),
#                      int(root.find('size')[1].text),
#                      label,
#                      xmin,
#                      ymin,
#                      xmax,
#                      ymax
#                      )
#             xml_list.append(value)
#     column_name = ['filename', 'width', 'height',
#                    'class', 'xmin', 'ymin', 'xmax', 'ymax']
#     xml_df = pd.DataFrame(xml_list, columns=column_name)
#     return xml_df

# %%
# def main():
#     datasets = ['path to dataset']
#     for ds in datasets:
#         xml_df = xml_to_csv(ds)
#         xml_df.to_csv('labels_{}.csv'.format(ds), index=None)
#         print('Successfully converted xml to csv.')

# main()

# %% [markdown]
# # **THIẾT LẬP CÁC THAM SỐ**

# %%
# import the necessary packages
import os
# define the base path to the input dataset and then use it to derive
# the path to the input images and annotation CSV files
BASE_PATH = "/content/drive/MyDrive/NLMH_OnkiemTra/Chap3_PhanloaiNhieudoituong/21022008/dataset"
IMAGES_PATH = os.path.sep.join([BASE_PATH, "images"])
ANNOTS_PATH = os.path.sep.join([BASE_PATH, "annotations"])

# %%
# define the path to the base output directory
BASE_OUTPUT = "/content/drive/MyDrive/NLMH_OnkiemTra/Chap3_PhanloaiNhieudoituong/21022008/output"
# define the path to the output model, label binarizer, plots output
# directory, and testing image paths
MODEL_PATH = os.path.sep.join([BASE_OUTPUT, "detector.h5"])
LB_PATH = os.path.sep.join([BASE_OUTPUT, "lb.pickle"])
PLOTS_PATH = os.path.sep.join([BASE_OUTPUT, "plots"])

# %%
# initialize our initial learning rate, number of epochs to train
# for, and the batch size
INIT_LR = 1e-4      # Tốc độ học
NUM_EPOCHS = 20
BATCH_SIZE = 32

# %% [markdown]
# # **HUẤN LUYỆN MÔ HÌNH**

# %% [markdown]
# ## **Import thư viện**

# %%
# import the necessary packages
from tensorflow.keras.applications import VGG19
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import pickle
import cv2
import os

# %% [markdown]
# ## **Load dữ liệu**

# %%
# initialize the list of data (images), class labels, target bounding
# box coordinates, and image paths
print("[INFO] loading dataset...")
data = []
labels = []
bboxes = []
imagePaths = []
# Out:
# [INFO] loading dataset...

# %%
# loop over all CSV files in the annotations directory
for csvPath in paths.list_files(ANNOTS_PATH, validExts=(".csv")):
	# load the contents of the current CSV annotations file
	rows = open(csvPath).read().strip().split("\n")
	# loop over the rows
	for row in rows:
		# break the row into the filename, bounding box coordinates,
		# and class label
		row = row.split(",")
		(filename, label,startX, startY, endX, endY) = row
		# derive the path to the input image, load the image (in
		# OpenCV format), and grab its dimensions
		imagePath = os.path.sep.join([IMAGES_PATH, label, filename])
		image = cv2.imread(imagePath)
		(h, w) = image.shape[:2]
		# scale the bounding box coordinates relative to the spatial
		# dimensions of the input image
		startX = float(startX) / w
		startY = float(startY) / h
		endX = float(endX) / w
		endY = float(endY) / h
		# load the image and preprocess it
		image = load_img(imagePath, target_size=(224, 224))
		image = img_to_array(image)
		# update our list of data, class labels, bounding boxes, and
		# image paths
		data.append(image)
		labels.append(label)
		bboxes.append((startX, startY, endX, endY))
		imagePaths.append(imagePath)
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:975: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
# convert the data, class labels, bounding boxes, and image paths to
# NumPy arrays, scaling the input pixel intensities from the range
# [0, 255] to [0, 1]
data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)
bboxes = np.array(bboxes, dtype="float32")
imagePaths = np.array(imagePaths)
# perform one-hot encoding on the labels
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
# only there are only two labels in the dataset, then we need to use
# Keras/TensorFlow's utility function as well
if len(lb.classes_) == 2:
	labels = to_categorical(labels)

# %% [markdown]
# ## **Phân chia dữ liệu**

# %%
split = train_test_split(data, labels, bboxes, imagePaths,test_size=0.20, random_state=42)
# unpack the data split
(trainImages, testImages) = split[:2]
(trainLabels, testLabels) = split[2:4]
(trainBBoxes, testBBoxes) = split[4:6]
(trainPaths, testPaths) = split[6:]

# %% [markdown]
# ## **Xây dựng mô hình**

# %%
# load the VGG16 network, ensuring the head FC layers are left off
vgg = VGG19(weights="imagenet", include_top=False, input_tensor=Input(shape=(224, 224, 3)))
vgg.trainable = False
flatten = vgg.output
flatten = Flatten()(flatten)
# construct a fully-connected layer header to output the predicted
# bounding box coordinates
bboxHead = Dense(128, activation="relu")(flatten)
bboxHead = Dense(64, activation="relu")(bboxHead)
bboxHead = Dense(32, activation="relu")(bboxHead)
bboxHead = Dense(4, activation="sigmoid",name="bounding_box")(bboxHead)
# construct a second fully-connected layer head, this one to predict
# the class label
softmaxHead = Dense(512, activation="relu")(flatten)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(512, activation="relu")(softmaxHead)
softmaxHead = Dropout(0.5)(softmaxHead)
softmaxHead = Dense(len(lb.classes_), activation="softmax",name="class_label")(softmaxHead)
# put together our model which accept an input image and then output
# bounding box coordinates and a class label
model = Model(inputs=vgg.input,outputs=(bboxHead, softmaxHead))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step

# %% [markdown]
# ## **Xác định loss và compile mô hình**

# %%
losses = {"class_label": "categorical_crossentropy","bounding_box": "mean_squared_error",}
lossWeights = {	"class_label": 1.0,	"bounding_box": 1.0}

# summary
opt = Adam(lr=INIT_LR)
model.compile(loss=losses, optimizer=opt, metrics=["accuracy"], loss_weights=lossWeights)
print(model.summary())
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 224, 224, 64  1792        ['input_1[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 224, 224, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 112, 112, 64  0           ['block1_conv2[0][0]']
#                                 )
#
#  block2_conv1 (Conv2D)          (None, 112, 112, 12  73856       ['block1_pool[0][0]']
#                                 8)
#
#  block2_conv2 (Conv2D)          (None, 112, 112, 12  147584      ['block2_conv1[0][0]']
#                                 8)
#
#  block2_pool (MaxPooling2D)     (None, 56, 56, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 56, 56, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 56, 56, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 28, 28, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 28, 28, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 28, 28, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 14, 14, 512)  0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 14, 14, 512)  2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 14, 14, 512)  2359808     ['block5_conv3[0][0]']
#
#  block5_pool (MaxPooling2D)     (None, 7, 7, 512)    0           ['block5_conv4[0][0]']
#
#  flatten (Flatten)              (None, 25088)        0           ['block5_pool[0][0]']
#
#  dense_3 (Dense)                (None, 512)          12845568    ['flatten[0][0]']
#
#  dense (Dense)                  (None, 128)          3211392     ['flatten[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense_3[0][0]']
#
#  dense_1 (Dense)                (None, 64)           8256        ['dense[0][0]']
#
#  dense_4 (Dense)                (None, 512)          262656      ['dropout[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['dense_4[0][0]']
#
#  bounding_box (Dense)           (None, 4)            132         ['dense_2[0][0]']
#
#  class_label (Dense)            (None, 3)            1539        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 36,356,007
# Trainable params: 16,331,623
# Non-trainable params: 20,024,384
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## **Huấn luyện mô hình**

# %%
trainTargets = {"class_label": trainLabels,"bounding_box": trainBBoxes}
testTargets = {	"class_label": testLabels,"bounding_box": testBBoxes}

# %%
print("[INFO] training model...")
H = model.fit(
	trainImages, trainTargets,
	validation_data=(testImages, testTargets),
	batch_size=BATCH_SIZE,
	epochs=NUM_EPOCHS,
	verbose=1)

# serialize the model to disk
print("[INFO] saving object detector model...")
model.save(MODEL_PATH, save_format="h5")

# serialize the label binarizer to disk
print("[INFO] saving label binarizer...")
f = open(LB_PATH, "wb")
f.write(pickle.dumps(lb))
f.close()
# Out:
# [INFO] training model...
# Epoch 1/20
# 10/10 [==============================] - 19s 427ms/step - loss: 3.7275 - bounding_box_loss: 0.0679 - class_label_loss: 3.6596 - bounding_box_accuracy: 0.4950 - class_label_accuracy: 0.3779 - val_loss: 2.9470 - val_bounding_box_loss: 0.0706 - val_class_label_loss: 2.8764 - val_bounding_box_accuracy: 0.4933 - val_class_label_accuracy: 0.5600
# Epoch 2/20
# 10/10 [==============================] - 2s 177ms/step - loss: 2.1157 - bounding_box_loss: 0.0518 - class_label_loss: 2.0639 - bounding_box_accuracy: 0.5686 - class_label_accuracy: 0.6221 - val_loss: 0.9722 - val_bounding_box_loss: 0.0565 - val_class_label_loss: 0.9156 - val_bounding_box_accuracy: 0.4933 - val_class_label_accuracy: 0.6800
# Epoch 3/20
# 10/10 [==============================] - 2s 178ms/step - loss: 0.9743 - bounding_box_loss: 0.0401 - class_label_loss: 0.9341 - bounding_box_accuracy: 0.5819 - class_label_accuracy: 0.7492 - val_loss: 0.2357 - val_bounding_box_loss: 0.0430 - val_class_label_loss: 0.1926 - val_bounding_box_accuracy: 0.4933 - val_class_label_accuracy: 0.9600
# Epoch 4/20
# 10/10 [==============================] - 2s 177ms/step - loss: 0.4044 - bounding_box_loss: 0.0292 - class_label_loss: 0.3752 - bounding_box_accuracy: 0.5585 - class_label_accuracy: 0.8595 - val_loss: 0.2031 - val_bounding_box_loss: 0.0565 - val_class_label_loss: 0.1466 - val_bounding_box_accuracy: 0.4933 - val_class_label_accuracy: 0.9733
# Epoch 5/20
# 10/10 [==============================] - 2s 177ms/step - loss: 0.3146 - bounding_box_loss: 0.0267 - class_label_loss: 0.2879 - bounding_box_accuracy: 0.5920 - class_label_accuracy: 0.8796 - val_loss: 0.1637 - val_bounding_box_loss: 0.0447 - val_class_label_loss: 0.1189 - val_bounding_box_accuracy: 0.5600 - val_class_label_accuracy: 0.9333
# Epoch 6/20
# 10/10 [==============================] - 2s 176ms/step - loss: 0.2734 - bounding_box_loss: 0.0236 - class_label_loss: 0.2498 - bounding_box_accuracy: 0.6355 - class_label_accuracy: 0.9164 - val_loss: 0.1225 - val_bounding_box_loss: 0.0442 - val_class_label_loss: 0.0783 - val_bounding_box_accuracy: 0.4800 - val_class_label_accuracy: 0.9867
# Epoch 7/20
# 10/10 [==============================] - 2s 177ms/step - loss: 0.1598 - bounding_box_loss: 0.0214 - class_label_loss: 0.1384 - bounding_box_accuracy: 0.6622 - class_label_accuracy: 0.9431 - val_loss: 0.1375 - val_bounding_box_loss: 0.0453 - val_class_label_loss: 0.0922 - val_bounding_box_accuracy: 0.5467 - val_class_label_accuracy: 0.9733
# Epoch 8/20
# 10/10 [==============================] - 2s 177ms/step - loss: 0.1207 - bounding_box_loss: 0.0212 - class_label_loss: 0.0995 - bounding_box_accuracy: 0.6856 - class_label_accuracy: 0.9799 - val_loss: 0.1116 - val_bounding_box_loss: 0.0396 - val_class_label_loss: 0.0720 - val_bounding_box_accuracy: 0.6000 - val_class_label_accuracy: 0.9867
# Epoch 9/20
# 10/10 [==============================] - 2s 179ms/step - loss: 0.1035 - bounding_box_loss: 0.0227 - class_label_loss: 0.0807 - bounding_box_accuracy: 0.6321 - class_label_accuracy: 0.9666 - val_loss: 0.1687 - val_bounding_box_loss: 0.0466 - val_class_label_loss: 0.1221 - val_bounding_box_accuracy: 0.5867 - val_class_label_accuracy: 0.9467
# Epoch 10/20
# 10/10 [==============================] - 2s 179ms/step - loss: 0.1195 - bounding_box_loss: 0.0265 - class_label_loss: 0.0930 - bounding_box_accuracy: 0.5518 - class_label_accuracy: 0.9632 - val_loss: 0.1343 - val_bounding_box_loss: 0.0469 - val_class_label_loss: 0.0874 - val_bounding_box_accuracy: 0.6133 - val_class_label_accuracy: 0.9733
# Epoch 11/20
# 10/10 [==============================] - 2s 181ms/step - loss: 0.1264 - bounding_box_loss: 0.0240 - class_label_loss: 0.1023 - bounding_box_accuracy: 0.5886 - class_label_accuracy: 0.9565 - val_loss: 0.1135 - val_bounding_box_loss: 0.0451 - val_class_label_loss: 0.0684 - val_bounding_box_accuracy: 0.6000 - val_class_label_accuracy: 0.9733
# Epoch 12/20
# 10/10 [==============================] - 2s 181ms/step - loss: 0.0897 - bounding_box_loss: 0.0218 - class_label_loss: 0.0679 - bounding_box_accuracy: 0.6722 - class_label_accuracy: 0.9732 - val_loss: 0.0889 - val_bounding_box_loss: 0.0436 - val_class_label_loss: 0.0452 - val_bounding_box_accuracy: 0.5600 - val_class_label_accuracy: 1.0000
# Epoch 13/20
# 10/10 [==============================] - 2s 181ms/step - loss: 0.0705 - bounding_box_loss: 0.0199 - class_label_loss: 0.0506 - bounding_box_accuracy: 0.6789 - class_label_accuracy: 0.9866 - val_loss: 0.2007 - val_bounding_box_loss: 0.0426 - val_class_label_loss: 0.1581 - val_bounding_box_accuracy: 0.5333 - val_class_label_accuracy: 0.9467
# Epoch 14/20
# 10/10 [==============================] - 2s 181ms/step - loss: 0.0722 - bounding_box_loss: 0.0180 - class_label_loss: 0.0542 - bounding_box_accuracy: 0.6689 - class_label_accuracy: 0.9732 - val_loss: 0.1004 - val_bounding_box_loss: 0.0411 - val_class_label_loss: 0.0593 - val_bounding_box_accuracy: 0.5467 - val_class_label_accuracy: 0.9733
# Epoch 15/20
# 10/10 [==============================] - 2s 182ms/step - loss: 0.0617 - bounding_box_loss: 0.0188 - class_label_loss: 0.0429 - bounding_box_accuracy: 0.6890 - class_label_accuracy: 0.9866 - val_loss: 0.1039 - val_bounding_box_loss: 0.0464 - val_class_label_loss: 0.0575 - val_bounding_box_accuracy: 0.5200 - val_class_label_accuracy: 0.9733
# Epoch 16/20
# 10/10 [==============================] - 2s 183ms/step - loss: 0.0528 - bounding_box_loss: 0.0190 - class_label_loss: 0.0338 - bounding_box_accuracy: 0.6689 - class_label_accuracy: 0.9900 - val_loss: 0.1209 - val_bounding_box_loss: 0.0469 - val_class_label_loss: 0.0740 - val_bounding_box_accuracy: 0.5067 - val_class_label_accuracy: 0.9600
# Epoch 17/20
# 10/10 [==============================] - 2s 182ms/step - loss: 0.0487 - bounding_box_loss: 0.0185 - class_label_loss: 0.0303 - bounding_box_accuracy: 0.6990 - class_label_accuracy: 0.9866 - val_loss: 0.0887 - val_bounding_box_loss: 0.0396 - val_class_label_loss: 0.0491 - val_bounding_box_accuracy: 0.6000 - val_class_label_accuracy: 0.9733
# Epoch 18/20
# 10/10 [==============================] - 2s 184ms/step - loss: 0.0870 - bounding_box_loss: 0.0200 - class_label_loss: 0.0670 - bounding_box_accuracy: 0.6823 - class_label_accuracy: 0.9699 - val_loss: 0.0796 - val_bounding_box_loss: 0.0441 - val_class_label_loss: 0.0355 - val_bounding_box_accuracy: 0.5067 - val_class_label_accuracy: 1.0000
# Epoch 19/20
# 10/10 [==============================] - 2s 182ms/step - loss: 0.0343 - bounding_box_loss: 0.0198 - class_label_loss: 0.0145 - bounding_box_accuracy: 0.6923 - class_label_accuracy: 0.9967 - val_loss: 0.1363 - val_bounding_box_loss: 0.0450 - val_class_label_loss: 0.0913 - val_bounding_box_accuracy: 0.4933 - val_class_label_accuracy: 0.9600
# Epoch 20/20
# 10/10 [==============================] - 2s 183ms/step - loss: 0.0711 - bounding_box_loss: 0.0194 - class_label_loss: 0.0517 - bounding_box_accuracy: 0.6722 - class_label_accuracy: 0.9799 - val_loss: 0.1604 - val_bounding_box_loss: 0.0436 - val_class_label_loss: 0.1168 - val_bounding_box_accuracy: 0.5067 - val_class_label_accuracy: 0.9600
# [INFO] saving object detector model...
# [INFO] saving label binarizer...

# %% [markdown]
# ## **Hiển thị loss và accuracy**

# %%
# plot the total loss, label loss, and bounding box loss
lossNames = ["loss", "class_label_loss", "bounding_box_loss"]
N = np.arange(0, NUM_EPOCHS)
plt.style.use("ggplot")
(fig, ax) = plt.subplots(3, 1, figsize=(13, 13))

# loop over the loss names
for (i, l) in enumerate(lossNames):
	# plot the loss for both the training and validation data
	title = "Loss for {}".format(l) if l != "loss" else "Total loss"
	ax[i].set_title(title)
	ax[i].set_xlabel("Epoch #")
	ax[i].set_ylabel("Loss")
	ax[i].plot(N, H.history[l], label=l)
	ax[i].plot(N, H.history["val_" + l], label="val_" + l)
	ax[i].legend()

# save the losses figure and create a new figure for the accuracies
plt.tight_layout()
plotPath = os.path.sep.join([PLOTS_PATH, "losses.png"])
plt.savefig(plotPath)
plt.close()

# %%
# create a new figure for the accuracies
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["class_label_accuracy"],
	label="class_label_train_acc")
plt.plot(N, H.history["val_class_label_accuracy"],
	label="val_class_label_acc")
plt.title("Class Label Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")

# save the accuracies plot
plotPath = os.path.sep.join([PLOTS_PATH, "accs.png"])
plt.savefig(plotPath)

# %% [markdown]
# # **KIỂM THỬ MÔ HÌNH**

# %% [markdown]
# ## **Import thư viện**

# %%
# import the necessary packages
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.models import load_model
import numpy as np
import mimetypes
import argparse
import imutils
import pickle
import cv2
import os

# %% [markdown]
# ## **Load mô hình**

# %%
print("[INFO] loading object detector...")
model = load_model(MODEL_PATH)
# Out:
# [INFO] loading object detector...

# %% [markdown]
# ## **Dự đoán hình ảnh bất kỳ**

# %%
from google.colab.patches import cv2_imshow

image = load_img(imagePath, target_size=(224, 224))
image = img_to_array(image) / 255.0
image = np.expand_dims(image, axis=0)

# make bounding box predictions on the input image
(boxPreds, labelPreds) = model.predict(image)
(startX, startY, endX, endY) = boxPreds[0]

# load the input image (in OpenCV format), resize it such that it
# fits on our screen, and grab its dimensions
image = cv2.imread(imagePath)
image = imutils.resize(image, width=600)
(h, w) = image.shape[:2]

# scale the predicted bounding box coordinates based on the image
# dimensions
startX = int(startX * w)
startY = int(startY * h)
endX = int(endX * w)
endY = int(endY * h)

# Draw the predicted bounding box
i = np.argmax(labelPreds, axis=1)
label = lb.classes_[i][0]
cv2.putText(image, label, (startX, startY - 10), cv2.FONT_HERSHEY_SIMPLEX,0.65, (0, 255, 0), 2)
cv2.rectangle(image, (startX, startY), (endX, endY),(0, 255, 0), 2)

# Hiển thị hình ảnh
cv2_imshow(image)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDB24DB0460>

# %%
from google.colab.patches import cv2_imshow

path_img_test = '/content/drive/MyDrive/NLMH_OnkiemTra/Chap3_PhanloaiNhieudoituong/21022008/dataset/images/banana/banana_33.jpg'

image = load_img(path_img_test, target_size=(224, 224))
image = img_to_array(image) / 255.0
image = np.expand_dims(image, axis=0)

# make bounding box predictions on the input image
(boxPreds, labelPreds) = model.predict(image)
(startX, startY, endX, endY) = boxPreds[0]

# load the input image (in OpenCV format), resize it such that it
# fits on our screen, and grab its dimensions
image = cv2.imread(path_img_test)
image = imutils.resize(image, width=600)
(h, w) = image.shape[:2]

# scale the predicted bounding box coordinates based on the image
# dimensions
startX = int(startX * w)
startY = int(startY * h)
endX = int(endX * w)
endY = int(endY * h)

# Draw the predicted bounding box
i = np.argmax(labelPreds, axis=1)
label = lb.classes_[i][0]
cv2.putText(image, label, (startX, startY - 10), cv2.FONT_HERSHEY_SIMPLEX,0.65, (0, 255, 0), 2)
cv2.rectangle(image, (startX, startY), (endX, endY),(0, 255, 0), 2)

# Hiển thị hình ảnh
cv2_imshow(image)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# <PIL.Image.Image image mode=RGB size=600x427 at 0x7FDB24DB1870>

# %%
boxPreds
# Out:
# array([[0.4599378 , 0.16297902, 0.71852565, 0.6675944 ]], dtype=float32)

# %%
from google.colab.patches import cv2_imshow

path_img_test = '/content/drive/MyDrive/NLMH_OnkiemTra/Chap3_PhanloaiNhieudoituong/21022008/dataset/images/banana/banana_33.jpg'

image = load_img(path_img_test, target_size=(224, 224))
image = img_to_array(image) / 255.0
image = np.expand_dims(image, axis=0)

# Thực hiện dự đoán hình ảnh với mô hình
(boxPreds, labelPreds) = model.predict(image)

# Lấy tọa độ hộp giới hạn dự đoán
(startX, startY, endX, endY) = boxPreds[0]

# Tải lại hình ảnh và điều chỉnh kích thước
image = cv2.imread(path_img_test)
image = imutils.resize(image, width=600)
(h, w) = image.shape[:2]

# Tính toán tọa độ hộp giới hạn dựa trên dự đoán
startX = int(startX * w)
startY = int(startY * h)
endX = int(endX * w)
endY = int(endY * h)

# Chọn nhãn và xác suất dự đoán cao nhất
i = np.argmax(labelPreds, axis=1)
label = lb.classes_[i][0]
confidence = np.max(labelPreds)

# Tạo nhãn với xác suất dự đoán
label_with_confidence = "{}: {:.2f}%".format(label, confidence * 100)

# Vẽ hộp giới hạn và nhãn
cv2.putText(image, label_with_confidence, (startX, startY - 10), cv2.FONT_HERSHEY_SIMPLEX,0.65, (0, 255, 0), 2)
cv2.rectangle(image, (startX, startY), (endX, endY),(0, 255, 0), 2)

# Hiển thị hình ảnh
cv2_imshow(image)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# <PIL.Image.Image image mode=RGB size=600x427 at 0x7FDB24D62140>
