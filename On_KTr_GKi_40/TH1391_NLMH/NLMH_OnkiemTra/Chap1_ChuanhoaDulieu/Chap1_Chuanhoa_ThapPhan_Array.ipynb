# %%
import numpy as np

# %%
data_array = [6, 7, 7, 12, 13, 13, 15, 16, 19, 22]

# %%
# Tìm giá trị tuyệt đối lớn nhất
max_abs_value = np.max(np.abs(data_array))

# Tính số chữ số của giá trị tuyệt đối lớn nhất
k = np.ceil(np.log10(max_abs_value))

# Chuẩn hóa dữ liệu với thang thập phân
decimal_scaled_data = data_array / (10 ** k)

print("Dữ liệu sau khi chuẩn hóa với thang thập phân:")
print(decimal_scaled_data)
# Out:
# Dữ liệu sau khi chuẩn hóa với thang thập phân:
# [0.06 0.07 0.07 0.12 0.13 0.13 0.15 0.16 0.19 0.22]
