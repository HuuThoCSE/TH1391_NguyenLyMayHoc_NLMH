# %%
# import thư viện

import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
# Khởi tạo frame dữ liệu

data = {'weight':[300, 250, 800],
        'price':[3, 2, 5]}
df = pd.DataFrame(data)
print(df)
# Out:
#    weight  price
# 0     300      3
# 1     250      2
# 2     800      5

# %%
# Chuẩn hóa dữ liệu

scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(df)
print(normalized_data)
# Out:
# [[0.09090909 0.33333333]
#  [0.         0.        ]
#  [1.         1.        ]]

# %%
# Chuyển đổi mảng chuẩn hóa thành khung dữ liệu

normalized_df = pd.DataFrame(normalized_data, columns=df.columns)
print(normalized_df)
# Out:
#      weight     price
# 0  0.090909  0.333333
# 1  0.000000  0.000000
# 2  1.000000  1.000000
