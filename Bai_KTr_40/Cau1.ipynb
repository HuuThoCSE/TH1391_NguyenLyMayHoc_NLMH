# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Đọc dữ liệu từ tập tin CSV
dfdata = pd.read_csv("/content/drive/MyDrive/BaiKiemTra/fruit.csv")
dfdata.head()
# Out:
#    ID  sweetness  sourness fruit type
# 0   1          6         4      sweet
# 1   2          9         1      sweet
# 2   3          8         2      sweet
# 3   4          9         1      sweet
# 4   5          7         3      sweet

# %%
X = dfdata.iloc[:, 1:-1]
y = dfdata['fruit type']

# %%
X
# Out:
#     sweetness  sourness
# 0           6         4
# 1           9         1
# 2           8         2
# 3           9         1
# 4           7         3
# 5          10         0
# 6           1         9
# 7           2         8
# 8           3         7
# 9           2         8
# 10          4         6

# %%
X_train = X[:-1]
X_train
# Out:
#    sweetness  sourness
# 0          6         4
# 1          9         1
# 2          8         2
# 3          9         1
# 4          7         3
# 5         10         0
# 6          1         9
# 7          2         8
# 8          3         7
# 9          2         8

# %%
y
# Out:
# 0     sweet
# 1     sweet
# 2     sweet
# 3     sweet
# 4     sweet
# 5     sweet
# 6      sour
# 7      sour
# 8      sour
# 9      sour
# 10      NaN
# Name: fruit type, dtype: object

# %%
y_train = y[:-1]
y_train
# Out:
# 0    sweet
# 1    sweet
# 2    sweet
# 3    sweet
# 4    sweet
# 5    sweet
# 6     sour
# 7     sour
# 8     sour
# 9     sour
# Name: fruit type, dtype: object

# %%
y_train_econder = LabelEncoder()
encoded_labels_y = y_train_econder.fit_transform(y_train)
y_train_le = encoded_labels_y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f57fefdd22be> in <cell line: 1>()
# ----> 1 y_train_econder = LabelEncoder()
#       2 encoded_labels_y = y_train_econder.fit_transform(y_train)
#       3 y_train_le = encoded_labels_y
#
# NameError: name 'LabelEncoder' is not defined

# %%
# Chuyển đổi đặc trưng và mục tiêu sang dạng mảng numpy
# X = np.array(X)
# y = np.array(y)

# %%
# Chia dữ liệu
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier

# Khởi tạo và huấn luyện mô hình KNN
k = 20
p = 2
knn = KNeighborsClassifier(n_neighbors=k, p=p)
knn.fit(X_train, y_train_le)

# Dự đoán trên tập test
y_pred = knn.predict(X_test)
